# %% [markdown]
# Memory Task

# %% [markdown]
# Long Term Intervention

# %%
import scipy.stats as stats

# Data for Pre and Post intervention
pre_scores = [5, 5, 4, 4, 2, 3, 5, 3]
post_scores = [5, 5, 5, 5, 3, 5, 5, 5]

# Calculate the paired t-test to find the p-value
t_stat, p_value = stats.ttest_rel(post_scores, pre_scores)
p_value
# Out:
# 0.020937570206924612

# %% [markdown]
# Short Term Intervention

# %%
# New data for Pre and Post intervention
new_pre_scores = [5, 3, 5, 5, 1, 4, 5, 4]
new_post_scores = [5, 5, 5, 5, 3, 5, 5, 5]

# Calculate the paired t-test for the new dataset
new_t_stat, new_p_value = stats.ttest_rel(new_post_scores, new_pre_scores)
new_p_value
# Out:
# 0.047944772179623375

# %% [markdown]
# Short Term Control

# %%
# Third set of participant scores for Pre and Post intervention
third_pre_scores = [5, 3, 3, 5, 4, 3, 3, 4]
third_post_scores = [5, 5, 5, 5, 4, 5, 5, 5]

# Calculate the paired t-test for the third dataset
third_t_stat, third_p_value = stats.ttest_rel(third_post_scores, third_pre_scores)
third_p_value
# Out:
# 0.014842060499958419

# %% [markdown]
# Digit Span

# %% [markdown]
# Long Term Intervention

# %%
# Fourth set of participant scores for Pre and Post intervention
fourth_pre_scores = [8, 6, 6, 6, 9, 6, 6, 9]
fourth_post_scores = [9, 9, 8, 7, 8, 6, 9, 9]

# Calculate the paired t-test for the fourth dataset
fourth_t_stat, fourth_p_value = stats.ttest_rel(fourth_post_scores, fourth_pre_scores)
fourth_p_value
# Out:
# 0.06536793800277121

# %% [markdown]
# Short Term Intervention

# %%
# Fifth set of participant scores for Pre and Post intervention
fifth_pre_scores = [6, 7, 5, 9, 6, 7, 6, 5]
fifth_post_scores = [7, 7, 6, 9, 7, 7, 6, 6]

# Calculate the paired t-test for the fifth dataset
fifth_t_stat, fifth_p_value = stats.ttest_rel(fifth_post_scores, fifth_pre_scores)
fifth_p_value
# Out:
# 0.033145500263773664

# %% [markdown]
# Short Term Control

# %%
# Sixth set of participant scores for Pre and Post intervention
sixth_pre_scores = [6, 7, 5, 5, 5, 5, 8, 7]
sixth_post_scores = [6, 7, 5, 5, 7, 6, 9, 7]

# Calculate the paired t-test for the sixth dataset
sixth_t_stat, sixth_p_value = stats.ttest_rel(sixth_post_scores, sixth_pre_scores)
sixth_p_value
# Out:
# 0.10355171027145907

# %% [markdown]
# n-back

# %% [markdown]
# Long Term Intervention

# %%
import scipy.stats as stats

# Seventh set of participant scores for Pre and Post intervention
seventh_pre_scores = [71, 80, 44, 40, 38, 71, 100, 100]
seventh_post_scores = [100, 100, 75, 43, 33, 100, 82, 100]

# Calculate the paired t-test for the seventh dataset
seventh_t_stat, seventh_p_value = stats.ttest_rel(seventh_post_scores, seventh_pre_scores)
seventh_p_value
# Out:
# 0.13379440400207845

# %% [markdown]
# Short Term Intervention

# %%
# Eighth set of participant scores for Pre and Post intervention
eighth_pre_scores = [56, 80, 50, 100, 75, 20, 86, 0]
eighth_post_scores = [60, 100, 50, 100, 88, 40, 88, 38]

# Calculate the paired t-test for the eighth dataset
eighth_t_stat, eighth_p_value = stats.ttest_rel(eighth_post_scores, eighth_pre_scores)
eighth_p_value
# Out:
# 0.037587224029723934

# %% [markdown]
# Short Term Control

# %%
# Ninth set of participant scores for Pre and Post intervention
ninth_pre_scores = [88, 90, 82, 75, 89, 88, 67, 67]
ninth_post_scores = [100, 75, 100, 73, 100, 67, 100, 86]

# Calculate the paired t-test for the ninth dataset
ninth_t_stat, ninth_p_value = stats.ttest_rel(ninth_post_scores, ninth_pre_scores)
ninth_p_value
# Out:
# 0.3219598570100721

# %%
from scipy.stats import ttest_ind

# Theta band powers for Short Term Intervention Group
theta_intervention = [24.884900508304263, 7117.545977728865, 1605.1300184561278, 212.4585238193192, 19545.831547523805, 50.75148526080426, 38282.634267708054, 36540.28640309197]

# Theta band powers for Short Term Control Group
theta_control = [85.47188208056212, 1938.3599378815386, 13564.920542292248, 685.0214913033153, 10008.366727835077, 4880.414458787328, 101623.63682323517, 9549.39833125308]

# Perform t-test
t_stat, p_value = ttest_ind(theta_intervention, theta_control)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: -0.36261885852432096
# P-value: 0.7223054471532365

# %%
from scipy.stats import ttest_ind

# Theta band powers for Short Term Intervention Group
theta_intervention = [21.604037244243695, 1527.1120270494982, 378.2471484560688, 50.86954668739207, 6742.301350871964, 30.019045102057618, 6482.933286302272, 7331.321430131113]


# Theta band powers for Short Term Control Group
theta_control = [16.56079570710244, 610.5577019927589, 3716.839825927486, 135.1337403449193, 2550.5564630250838, 511.1517205804864, 64389.00588991573, 2194.6217304423326]

# Perform t-test
t_stat, p_value = ttest_ind(theta_intervention, theta_control)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: -0.80776931190792
# P-value: 0.4327346048996148

# %%
from scipy.stats import ttest_ind

# Theta band powers for Short Term Intervention Group
theta_intervention = [90.25314633564409, 934.8651270057384, 277.91533337531894, 72.76987534327104, 7828.891421539663, 24.34222922399491, 2939.7046412725927, 2832.7483231273877]



# Theta band powers for Short Term Control Group
theta_control = [34.90519691575409, 315.07502106944776, 2749.2776054090173, 124.74774249299506, 890.2116072246629, 267.1257504538302, 67057.58449947217, 1492.5660230920805]

# Perform t-test
t_stat, p_value = ttest_ind(theta_intervention, theta_control)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: -0.8684461642728396
# P-value: 0.39979300441730903

# %%
from scipy.stats import ttest_ind

# Theta band powers for Short Term Intervention Group
theta_intervention = [386.89762246338677, 99.56886461082976, 79.4973062560148, 34.76440264319309, 1675.511691412178, 15.805172571770184, 248.4776421885012, 197.59534705603068]



# Theta band powers for Short Term Control Group
theta_control = [36.22233021829923, 103.58473604572846, 355.1917844787323, 41.705635992730045, 109.0630580888956, 60.09965738403816, 12471.593618148354, 279.46218887715884]

# Perform t-test
t_stat, p_value = ttest_ind(theta_intervention, theta_control)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: -0.862063597448981
# P-value: 0.40317755754905005

# %%
from scipy.stats import ttest_ind

# Data for Short Term Intervention Group
theta_intervention = [24.884900508304263, 7117.545977728865, 1605.1300184561278, 212.4585238193192, 19545.831547523805, 50.75148526080426, 38282.634267708054, 36540.28640309197]
alpha_intervention = [21.604037244243695, 1527.1120270494982, 378.2471484560688, 50.86954668739207, 6742.301350871964, 30.019045102057618, 6482.933286302272, 7331.321430131113]
beta_intervention = [90.25314633564409, 934.8651270057384, 277.91533337531894, 72.76987534327104, 7828.891421539663, 24.34222922399491, 2939.7046412725927, 2832.7483231273877]
gamma_intervention = [386.89762246338677, 99.56886461082976, 79.4973062560148, 34.76440264319309, 1675.511691412178, 15.805172571770184, 248.4776421885012, 197.59534705603068]

# Data for Short Term Control Group
theta_control = [85.47188208056212, 1938.3599378815386, 13564.920542292248, 685.0214913033153, 10008.366727835077, 4880.414458787328, 101623.63682323517, 9549.39833125308]
alpha_control = [16.56079570710244, 610.5577019927589, 3716.839825927486, 135.1337403449193, 2550.5564630250838, 511.1517205804864, 64389.00588991573, 2194.6217304423326]
beta_control = [34.90519691575409, 315.07502106944776, 2749.2776054090173, 124.74774249299506, 890.2116072246629, 267.1257504538302, 67057.58449947217, 1492.5660230920805]
gamma_control = [36.22233021829923, 103.58473604572846, 355.1917844787323, 41.705635992730045, 109.0630580888956, 60.09965738403816, 12471.593618148354, 279.46218887715884]

# Perform t-tests
t_stat_theta, p_val_theta = ttest_ind(theta_intervention, theta_control)
t_stat_alpha, p_val_alpha = ttest_ind(alpha_intervention, alpha_control)
t_stat_beta, p_val_beta = ttest_ind(beta_intervention, beta_control)
t_stat_gamma, p_val_gamma = ttest_ind(gamma_intervention, gamma_control)

# Print results
print(f"Theta band: t-statistic = {t_stat_theta}, p-value = {p_val_theta}")
print(f"Alpha band: t-statistic = {t_stat_alpha}, p-value = {p_val_alpha}")
print(f"Beta band: t-statistic = {t_stat_beta}, p-value = {p_val_beta}")
print(f"Gamma band: t-statistic = {t_stat_gamma}, p-value = {p_val_gamma}")
# Out:
# Theta band: t-statistic = -0.36261885852432096, p-value = 0.7223054471532365
# Alpha band: t-statistic = -0.80776931190792, p-value = 0.4327346048996148
# Beta band: t-statistic = -0.8684461642728396, p-value = 0.39979300441730903
# Gamma band: t-statistic = -0.862063597448981, p-value = 0.40317755754905005

# %%
from scipy.stats import ttest_rel

# First session band powers for each frequency band
first_session_band_powers = {
    'Theta': [261.05853567438476, 97083.70574052601, 5335.134257582832, 3450.7368326996243, 42.02132360400447, 64863.743116290425, 7286.792588038693, 82.86169127899956],
    'Alpha': [63.81240757810656, 14478.714418163561, 950.668695105109, 1125.6889315976116, 33.01364255454839, 13206.25769967221, 10610.925889764692, 10.678941024325642],
    'Beta': [83.75305943404577, 5437.45685294748, 1042.3056841748053, 355.77786682937403, 26.454079308091387, 5038.657056740291, 1630.5486137161697, 11.094611816296519],
    'Gamma': [114.05416101544368, 494.6833147816915, 251.42770602697627, 90.21508995883315, 18.67722458823621, 309.06442957319905, 817.7304239600805, 6.125813307192256]
}

# Last session band powers for each frequency band
last_session_band_powers = {
    'Theta': [136.31286957015982, 195573.14848610276, 85154.36280121624, 22111.371448602375, 111.12594845513048, 606.0676786198817, 137.7121405512156, 1013.8658920503312],
    'Alpha': [63.69896573103807, 57971.81386847825, 19846.590293907215, 1126.550867912669, 66.64607882867844, 132.5564913363341, 241.88811988890163, 251.81886510783838],
    'Beta': [72.72273472215498, 51532.81771949911, 15364.215515171434, 455.0052002270193, 38.21120522151469, 133.54781520089088, 60.30712029728661, 233.4062171120419],
    'Gamma': [89.84845039766297, 11144.556381772047, 2319.6104358248845, 69.47596555244296, 17.81486957529453, 35.78387733830067, 12.059415681938551, 55.454301406751206]
}

# Function to calculate p-values
def calculate_p_values(first_session, last_session):
    p_values = {}
    for band in first_session:
        t_stat, p_val = ttest_rel(first_session[band], last_session[band])
        p_values[band] = p_val
    return p_values

# Calculate p-values
p_values = calculate_p_values(first_session_band_powers, last_session_band_powers)
print(p_values)
# Out:
# {'Theta': 0.4145891532276996, 'Alpha': 0.4724793906750223, 'Beta': 0.2924417505936434, 'Gamma': 0.31548744760504216}

# %%
from scipy.stats import ttest_rel

# First session band powers for each frequency band
first_session_band_powers = {
    'Theta': [261.05853567438476, 97083.70574052601, 5335.134257582832, 3450.7368326996243, 42.02132360400447, 64863.743116290425, 7286.792588038693, 82.86169127899956],
    'Alpha': [63.81240757810656, 14478.714418163561, 950.668695105109, 1125.6889315976116, 33.01364255454839, 13206.25769967221, 10610.925889764692, 10.678941024325642],
    'Beta': [83.75305943404577, 5437.45685294748, 1042.3056841748053, 355.77786682937403, 26.454079308091387, 5038.657056740291, 1630.5486137161697, 11.094611816296519],
    'Gamma': [114.05416101544368, 494.6833147816915, 251.42770602697627, 90.21508995883315, 18.67722458823621, 309.06442957319905, 817.7304239600805, 6.125813307192256]
}

# Last session band powers for each frequency band
last_session_band_powers = {
    'Theta': [136.31286957015982, 195573.14848610276, 85154.36280121624, 22111.371448602375, 111.12594845513048, 606.0676786198817, 137.7121405512156, 1013.8658920503312],
    'Alpha': [63.69896573103807, 57971.81386847825, 19846.590293907215, 1126.550867912669, 66.64607882867844, 132.5564913363341, 241.88811988890163, 251.81886510783838],
    'Beta': [72.72273472215498, 51532.81771949911, 15364.215515171434, 455.0052002270193, 38.21120522151469, 133.54781520089088, 60.30712029728661, 233.4062171120419],
    'Gamma': [89.84845039766297, 11144.556381772047, 2319.6104358248845, 69.47596555244296, 17.81486957529453, 35.78387733830067, 12.059415681938551, 55.454301406751206]
}

# Calculate p-values for each participant
def calculate_individual_p_values(first_session, last_session):
    p_values = {band: [] for band in first_session.keys()}
    for band in first_session.keys():
        for i in range(len(first_session[band])):
            t_stat, p_val = ttest_rel([first_session[band][i]], [last_session[band][i]])
            p_values[band].append(p_val)
    return p_values

# Calculate individual p-values
individual_p_values = calculate_individual_p_values(first_session_band_powers, last_session_band_powers)

# Print individual p-values
for band in individual_p_values:
    print(f"{band} band p-values: {individual_p_values[band]}")
# Out:
# Theta band p-values: [nan, nan, nan, nan, nan, nan, nan, nan]
# Alpha band p-values: [nan, nan, nan, nan, nan, nan, nan, nan]
# Beta band p-values: [nan, nan, nan, nan, nan, nan, nan, nan]
# Gamma band p-values: [nan, nan, nan, nan, nan, nan, nan, nan]

# %%
from scipy.stats import ttest_rel

# First session band powers for each frequency band
first_session_band_powers = {
    'Theta': [261.05853567438476, 97083.70574052601, 5335.134257582832, 3450.7368326996243, 42.02132360400447, 64863.743116290425, 7286.792588038693, 82.86169127899956],
    'Alpha': [63.81240757810656, 14478.714418163561, 950.668695105109, 1125.6889315976116, 33.01364255454839, 13206.25769967221, 10610.925889764692, 10.678941024325642],
    'Beta': [83.75305943404577, 5437.45685294748, 1042.3056841748053, 355.77786682937403, 26.454079308091387, 5038.657056740291, 1630.5486137161697, 11.094611816296519],
    'Gamma': [114.05416101544368, 494.6833147816915, 251.42770602697627, 90.21508995883315, 18.67722458823621, 309.06442957319905, 817.7304239600805, 6.125813307192256]
}

# Last session band powers for each frequency band
last_session_band_powers = {
    'Theta': [136.31286957015982, 195573.14848610276, 85154.36280121624, 22111.371448602375, 111.12594845513048, 606.0676786198817, 137.7121405512156, 1013.8658920503312],
    'Alpha': [63.69896573103807, 57971.81386847825, 19846.590293907215, 1126.550867912669, 66.64607882867844, 132.5564913363341, 241.88811988890163, 251.81886510783838],
    'Beta': [72.72273472215498, 51532.81771949911, 15364.215515171434, 455.0052002270193, 38.21120522151469, 133.54781520089088, 60.30712029728661, 233.4062171120419],
    'Gamma': [89.84845039766297, 11144.556381772047, 2319.6104358248845, 69.47596555244296, 17.81486957529453, 35.78387733830067, 12.059415681938551, 55.454301406751206]
}

# Calculate paired differences for each participant and each band
paired_differences = {band: [] for band in first_session_band_powers.keys()}
for band in first_session_band_powers.keys():
    for i in range(len(first_session_band_powers[band])):
        paired_differences[band].append(first_session_band_powers[band][i] - last_session_band_powers[band][i])

# Print paired differences for each band and participant
for band in paired_differences.keys():
    print(f"{band} band paired differences: {paired_differences[band]}")

# If you want to calculate some simple statistics (mean, standard deviation) for the differences:
import numpy as np

stats = {band: {'mean': np.mean(paired_differences[band]), 'std': np.std(paired_differences[band])} for band in paired_differences.keys()}
for band in stats.keys():
    print(f"{band} band stats - Mean: {stats[band]['mean']}, Std: {stats[band]['std']}")
# Out:
# Theta band paired differences: [124.74566610422494, -98489.44274557674, -79819.2285436334, -18660.63461590275, -69.104624851126, 64257.67543767054, 7149.080447487478, -931.0042007713316]
# Alpha band paired differences: [0.11344184706848637, -43493.099450314694, -18895.921598802106, -0.8619363150573918, -33.63243627413005, 13073.701208335875, 10369.037769875791, -241.13992408351274]
# Beta band paired differences: [11.030324711890785, -46095.36086655163, -14321.909830996628, -99.22733339764528, -11.757125913423302, 4905.1092415394005, 1570.241493418883, -222.31160529574538]
# Gamma band paired differences: [24.20571061778071, -10649.873066990356, -2068.182729797908, 20.73912440639019, 0.8623550129416806, 273.2805522348984, 805.671008278142, -49.32848809955895]
# Theta band stats - Mean: -15804.73914743414, Std: 48221.13895301215
# Alpha band stats - Mean: -4902.725365716346, Std: 17084.019260289155
# Beta band stats - Mean: -6783.023212810611, Std: 15765.506044888401
# ...

# %%
import numpy as np
import scipy.stats as stats

# Band powers for intervention group
intervention_band_powers = {
    'theta': [24.89, 7117.54, 1605.13, 212.46, 19545.83, 50.75, 38282.63, 36540.29],
    'alpha': [21.60, 1527.11, 378.25, 50.87, 6742.30, 30.02, 6482.93, 7331.32],
    'beta': [90.25, 934.86, 277.91, 72.77, 7828.89, 24.34, 2939.70, 2832.75],
    'gamma': [386.90, 99.57, 79.50, 34.76, 1675.51, 15.80, 248.48, 197.60]
}

# Band powers for control group
control_band_powers = {
    'theta': [85.47, 1938.36, 13564.92, 685.02, 10008.37, 4880.41, 101623.63, 9549.40],
    'alpha': [16.56, 610.56, 3716.84, 135.13, 2550.56, 511.15, 64389.00, 2194.62],
    'beta': [34.90, 315.07, 2749.28, 124.74, 890.21, 267.12, 67057.58, 1492.57],
    'gamma': [36.22, 103.58, 355.19, 41.70, 109.06, 60.10, 12471.59, 279.46]
}

# Function to calculate confidence interval
def calculate_confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std_err = stats.sem(data)
    h = std_err * stats.t.ppf((1 + confidence) / 2., n-1)
    return mean, mean - h, mean + h

# Calculate confidence intervals for each band power in the intervention group
print("Confidence Intervals for Intervention Group:")
for band, powers in intervention_band_powers.items():
    mean, lower, upper = calculate_confidence_interval(powers)
    print(f"{band.capitalize()} Band: Mean = {mean:.2f}, CI = [{lower:.2f}, {upper:.2f}]")

# Calculate confidence intervals for each band power in the control group
print("\nConfidence Intervals for Control Group:")
for band, powers in control_band_powers.items():
    mean, lower, upper = calculate_confidence_interval(powers)
    print(f"{band.capitalize()} Band: Mean = {mean:.2f}, CI = [{lower:.2f}, {upper:.2f}]")
# Out:
# Confidence Intervals for Intervention Group:
# Theta Band: Mean = 12922.44, CI = [-851.66, 26696.54]
# Alpha Band: Mean = 2820.55, CI = [-6.96, 5648.06]
# Beta Band: Mean = 1875.18, CI = [-376.81, 4127.18]
# Gamma Band: Mean = 342.26, CI = [-119.80, 804.33]
#
# Confidence Intervals for Control Group:
# Theta Band: Mean = 17791.95, CI = [-10818.95, 46402.84]
# Alpha Band: Mean = 9265.55, CI = [-9388.15, 27919.26]
# Beta Band: Mean = 9116.43, CI = [-10471.17, 28704.04]
# Gamma Band: Mean = 1682.11, CI = [-1963.91, 5328.13]

# %%
import numpy as np
import scipy.stats as stats

# Normalized band powers for each participant
normalized_band_powers = [
    {'theta': 0.23286796125238718, 'alpha': 0.22252448253906754, 'beta': 0.2608547357136297, 'gamma': 0.28375282049491557},
    {'theta': 0.21269811954128504, 'alpha': 0.21746792258374, 'beta': 0.27495760895645266, 'gamma': 0.2948763489185224},
    {'theta': 0.2556639793853376, 'alpha': 0.24599141079923403, 'beta': 0.24322722763596963, 'gamma': 0.2551173821794588},
    {'theta': 0.25640500292820895, 'alpha': 0.22579735697851674, 'beta': 0.24641467937688888, 'gamma': 0.27138296071638535},
    {'theta': 0.2449224580452346, 'alpha': 0.2416044062131151, 'beta': 0.25280755890921625, 'gamma': 0.2606655768324341},
    {'theta': 0.2227629451357043, 'alpha': 0.23058848564067988, 'beta': 0.26326507310543634, 'gamma': 0.2833834961181794},
    {'theta': 0.291876838092723, 'alpha': 0.27674543811514074, 'beta': 0.22021464449110023, 'gamma': 0.2111630793010361},
    {'theta': 0.2101710453504045, 'alpha': 0.21587229775640537, 'beta': 0.2244270989798932, 'gamma': 0.349529557913297},
]

# Extract band values into arrays
theta_values = [participant['theta'] for participant in normalized_band_powers]
alpha_values = [participant['alpha'] for participant in normalized_band_powers]
beta_values = [participant['beta'] for participant in normalized_band_powers]
gamma_values = [participant['gamma'] for participant in normalized_band_powers]

# Function to calculate mean, standard deviation, and confidence interval
def calculate_confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(len(data))
    h = std_err * stats.t.ppf((1 + confidence) / 2., len(data) - 1)
    return mean, mean - h, mean + h

# Calculate for each band
theta_mean, theta_ci_low, theta_ci_high = calculate_confidence_interval(theta_values)
alpha_mean, alpha_ci_low, alpha_ci_high = calculate_confidence_interval(alpha_values)
beta_mean, beta_ci_low, beta_ci_high = calculate_confidence_interval(beta_values)
gamma_mean, gamma_ci_low, gamma_ci_high = calculate_confidence_interval(gamma_values)

# Print results
print(f"Theta Band: Mean = {theta_mean:.4f}, CI = [{theta_ci_low:.4f}, {theta_ci_high:.4f}]")
print(f"Alpha Band: Mean = {alpha_mean:.4f}, CI = [{alpha_ci_low:.4f}, {alpha_ci_high:.4f}]")
print(f"Beta Band: Mean = {beta_mean:.4f}, CI = [{beta_ci_low:.4f}, {beta_ci_high:.4f}]")
print(f"Gamma Band: Mean = {gamma_mean:.4f}, CI = [{gamma_ci_low:.4f}, {gamma_ci_high:.4f}]")
# Out:
# Theta Band: Mean = 0.2409, CI = [0.2181, 0.2637]
# Alpha Band: Mean = 0.2346, CI = [0.2177, 0.2514]
# Beta Band: Mean = 0.2483, CI = [0.2325, 0.2641]
# Gamma Band: Mean = 0.2762, CI = [0.2434, 0.3090]

# %%
import numpy as np
import scipy.stats as stats

# Normalized band powers for the intervention group
intervention_group = [
    {'theta': 0.23088100463594924, 'alpha': 0.23287893642231297, 'beta': 0.2667433437214731, 'gamma': 0.26949671522026475},
    {'theta': 0.22362903345281238, 'alpha': 0.2456071258987452, 'beta': 0.25608985603756346, 'gamma': 0.27467398461087905},
    {'theta': 0.24855789189596544, 'alpha': 0.195873912990574, 'beta': 0.2504984064965227, 'gamma': 0.3050697886169379},
    {'theta': 0.12172324192047149, 'alpha': 0.09897365272565631, 'beta': 0.14953395796181812, 'gamma': 0.629769147392054},
    {'theta': 0.24912210806458426, 'alpha': 0.24548456468247293, 'beta': 0.2511987391455661, 'gamma': 0.25419458810737666},
    {'theta': 0.24849158712577193, 'alpha': 0.21428555318715709, 'beta': 0.26265893452263106, 'gamma': 0.2745639251644399},
    {'theta': 0.30559200064723063, 'alpha': 0.2596625969259376, 'beta': 0.21695714285081563, 'gamma': 0.21778825957601614},
    {'theta': 0.2464197165227399, 'alpha': 0.21602182867800937, 'beta': 0.2572010503772381, 'gamma': 0.28035740442201273}
]

# Function to calculate mean and confidence interval
def mean_confidence_interval(data, confidence=0.95):
    n = len(data)
    m = np.mean(data)
    se = stats.sem(data)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

# Extracting band powers and calculating statistics
bands = ['theta', 'alpha', 'beta', 'gamma']
band_stats = {}

for band in bands:
    band_data = [participant[band] for participant in intervention_group]
    mean, ci_low, ci_high = mean_confidence_interval(band_data)
    band_stats[band] = {'mean': mean, 'ci': (ci_low, ci_high)}

# Display results
for band in bands:
    print(f"{band.capitalize()} Band: Mean = {band_stats[band]['mean']:.4f}, CI = [{band_stats[band]['ci'][0]:.4f}, {band_stats[band]['ci'][1]:.4f}]")
# Out:
# Theta Band: Mean = 0.2343, CI = [0.1911, 0.2775]
# Alpha Band: Mean = 0.2136, CI = [0.1712, 0.2560]
# Beta Band: Mean = 0.2389, CI = [0.2061, 0.2716]
# Gamma Band: Mean = 0.3132, CI = [0.2043, 0.4222]

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
labels = ['Living with MCI', 'Not living with MCI']
sizes = [15, 85]  # Average of 12% to 18% is 15%
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the first slice (Living with MCI)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, shadow=True, startangle=140)

plt.title('Percentage of People Age 60 or Older Living with MCI')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import pandas as pd

# Provided data
data = {
    'Theta': [0.23, 0.22, 0.25, 0.12, 0.25, 0.25, 0.31, 0.25],
    'Alpha': [0.23, 0.25, 0.2, 0.1, 0.25, 0.21, 0.26, 0.22],
    'Beta': [0.27, 0.26, 0.25, 0.15, 0.25, 0.26, 0.22, 0.26],
    'Gamma': [0.27, 0.27, 0.31, 0.63, 0.25, 0.27, 0.22, 0.28]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Melt the DataFrame for seaborn
df_melted = df.melt(var_name='Frequency Band', value_name='Values')

# Create a boxplot
plt.figure(figsize=(12, 8))
palette = sns.color_palette("Set2")
sns.boxplot(x='Frequency Band', y='Values', data=df_melted, palette=palette)

# Calculate and plot means and confidence intervals
means = df.mean()
confidence_intervals = df.apply(lambda x: stats.t.interval(0.95, len(x)-1, loc=np.mean(x), scale=stats.sem(x)))

for i, col in enumerate(df.columns):
    mean = means[col]
    ci = confidence_intervals[col]
    plt.scatter(i, mean, color='red', zorder=3)
    plt.text(i, mean, f'{mean:.2f}', horizontalalignment='center', color='black')
    plt.errorbar(i, mean, yerr=[[mean-ci[0]], [ci[1]-mean]], fmt='o', color='black', capsize=5)

plt.title('Box and Whisker Plot with Mean and 95% Confidence Interval (SIG)')
plt.xlabel('Frequency Band')
plt.ylabel('Values')

plt.show()
# Out:
# <ipython-input-8-9eb1716cebb6>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Frequency Band', y='Values', data=df_melted, palette=palette)
# <ipython-input-8-9eb1716cebb6>:24: UserWarning: The palette list has more values (8) than needed (4), which may not be intended.
#   sns.boxplot(x='Frequency Band', y='Values', data=df_melted, palette=palette)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import pandas as pd

# Provided data
data = {
    'Theta': [0.23, 0.21, 0.26, 0.26, 0.24, 0.22, 0.29, 0.21],
    'Alpha': [0.22, 0.22, 0.25, 0.23, 0.24, 0.23, 0.28, 0.22],
    'Beta': [0.26, 0.27, 0.24, 0.25, 0.25, 0.26, 0.22, 0.22],
    'Gamma': [0.28, 0.29, 0.26, 0.27, 0.26, 0.28, 0.21, 0.35]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Melt the DataFrame for seaborn
df_melted = df.melt(var_name='Frequency Band', value_name='Values')

# Create a boxplot
plt.figure(figsize=(12, 8))
palette = sns.color_palette("Set2")
sns.boxplot(x='Frequency Band', y='Values', data=df_melted, palette=palette)

# Calculate and plot means and confidence intervals
means = df.mean()
confidence_intervals = df.apply(lambda x: stats.t.interval(0.95, len(x)-1, loc=np.mean(x), scale=stats.sem(x)))

for i, col in enumerate(df.columns):
    mean = means[col]
    ci = confidence_intervals[col]
    plt.scatter(i, mean, color='red', zorder=3)
    plt.text(i, mean, f'{mean:.2f}', horizontalalignment='center', color='black')
    plt.errorbar(i, mean, yerr=[[mean-ci[0]], [ci[1]-mean]], fmt='o', color='black', capsize=5)

plt.title('Box and Whisker Plot with Mean and 95% Confidence Interval (SCG)')
plt.xlabel('Frequency Band')
plt.ylabel('Values')

plt.show()
# Out:
# <ipython-input-9-8adc83c0e9b8>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Frequency Band', y='Values', data=df_melted, palette=palette)
# <ipython-input-9-8adc83c0e9b8>:24: UserWarning: The palette list has more values (8) than needed (4), which may not be intended.
#   sns.boxplot(x='Frequency Band', y='Values', data=df_melted, palette=palette)

# %%
import matplotlib.pyplot as plt
import numpy as np

# P-values for each frequency band for each participant
participants = ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8']
bands = ['Theta', 'Alpha', 'Beta', 'Gamma']

p_values = {
    'P1': [0.0019, 0.0972, 0.8449, 0.9398],
    'P2': [0.0139, 0.0209, 0.0015, 0.0013],
    'P3': [0.00009, 0.000003, 0.0644, 0.2998],
    'P4': [0.0711, 0.911, 0.0143, 0.0005],
    'P5': [0.00001, 0.000144, 0.000267, 0.0171],
    'P6': [0.0803, 0.0133, 0.0457, 0.0619],
    'P7': [0.000065, 0.1218, 0.0016, 0.00037],
    'P8': [0.2206, 0.1393, 0.7716, 0.3691],
}

# Transform p-values to -log10(p-values)
neg_log_p_values = {p: [-np.log10(v) for v in p_values[p]] for p in participants}

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

bar_width = 0.1
index = np.arange(len(bands))

for i, participant in enumerate(participants):
    plt.bar(index + i * bar_width, neg_log_p_values[participant], bar_width, label=participant)

# Significance threshold line
plt.axhline(y=-np.log10(0.05), color='r', linestyle='--', label='Significance Threshold (0.05)')

plt.xlabel('Frequency Band')
plt.ylabel('-log10(p-value)')
plt.title('P-values for Different Frequency Bands Across Participants')
plt.xticks(index + bar_width * (len(participants) / 2), bands)
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Let's try to generate the plot and save it again

import matplotlib.pyplot as plt
import numpy as np

# P-values for each frequency band for each participant
participants = ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8']
bands = ['Theta', 'Alpha', 'Beta', 'Gamma']

p_values = {
    'P1': [0.0019, 0.0972, 0.8449, 0.9398],
    'P2': [0.0139, 0.0209, 0.0015, 0.0013],
    'P3': [0.00009, 0.000003, 0.0644, 0.2998],
    'P4': [0.0711, 0.911, 0.0143, 0.0005],
    'P5': [0.00001, 0.000144, 0.000267, 0.0171],
    'P6': [0.0803, 0.0133, 0.0457, 0.0619],
    'P7': [0.000065, 0.1218, 0.0016, 0.00037],
    'P8': [0.2206, 0.1393, 0.7716, 0.3691],
}

# Transform p-values to -log10(p-values)
neg_log_p_values = {p: [-np.log10(v) for v in p_values[p]] for p in participants}

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

bar_width = 0.1
index = np.arange(len(bands))

for i, participant in enumerate(participants):
    plt.bar(index + i * bar_width, neg_log_p_values[participant], bar_width, label=participant)

# Significance threshold line
plt.axhline(y=-np.log10(0.05), color='r', linestyle='--', label='Significance Threshold (0.05)')

plt.xlabel('Frequency Band')
plt.ylabel('-log10(p-value)')
plt.title('P-values for Different Frequency Bands Across Participants')
plt.xticks(index + bar_width * (len(participants) / 2), bands)
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# First session band powers
first_session = {
    'theta': [0.2422, 0.2531, 0.2445, 0.2830, 0.2605, 0.2273, 0.2625, 0.2411],
    'alpha': [0.2148, 0.2289, 0.2264, 0.2239, 0.2294, 0.2436, 0.2172, 0.2565],
    'beta': [0.2474, 0.2419, 0.2478, 0.2490, 0.2376, 0.2504, 0.2360, 0.2463],
    'gamma': [0.2955, 0.2761, 0.2814, 0.2441, 0.2725, 0.2787, 0.2843, 0.2560]
}

# Last session band powers
last_session = {
    'theta': [0.2483, 0.2333, 0.2872, 0.2376, 0.2329, 0.2732, 0.2560, 0.2373],
    'alpha': [0.1955, 0.2548, 0.2563, 0.2023, 0.2546, 0.2501, 0.2343, 0.2425],
    'beta': [0.2477, 0.2406, 0.2000, 0.2616, 0.2300, 0.2353, 0.2322, 0.2486],
    'gamma': [0.3085, 0.2713, 0.2565, 0.2986, 0.2825, 0.2414, 0.2775, 0.2716]
}

# Calculate means and standard deviations
first_means = {band: np.mean(powers) for band, powers in first_session.items()}
first_sds = {band: np.std(powers) for band, powers in first_session.items()}
last_means = {band: np.mean(powers) for band, powers in last_session.items()}
last_sds = {band: np.std(powers) for band, powers in last_session.items()}

# Plotting
bands = ['theta', 'alpha', 'beta', 'gamma']
x = np.arange(len(bands))

fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.35
error_kw = dict(lw=1, capsize=3, capthick=1)

# First session bars
rects1 = ax.bar(x - bar_width/2, list(first_means.values()), bar_width,
                yerr=list(first_sds.values()), error_kw=error_kw,
                label='First Session', color='skyblue')

# Last session bars
rects2 = ax.bar(x + bar_width/2, list(last_means.values()), bar_width,
                yerr=list(last_sds.values()), error_kw=error_kw,
                label='Last Session', color='lightgreen')

ax.set_xlabel('Frequency Band')
ax.set_ylabel('Normalized Band Power')
ax.set_title('Comparison of Normalized Band Powers Before and After Intervention')
ax.set_xticks(x)
ax.set_xticklabels(bands)
ax.legend()

plt.tight_layout()
plt.show()

# %%
from scipy.stats import ttest_rel

# Paired t-tests
for band in bands:
    t_stat, p_value = ttest_rel(first_session[band], last_session[band])
    print(f'{band.capitalize()} Band: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}')
# Out:
# Theta Band: t-statistic = 0.0924, p-value = 0.9290
# Alpha Band: t-statistic = -0.8141, p-value = 0.4424
# Beta Band: t-statistic = 1.1794, p-value = 0.2768
# Gamma Band: t-statistic = -0.2431, p-value = 0.8149

# %%
import pandas as pd

# First session band powers
first_session = {
    'Participant 1': {'theta': 0.2422, 'alpha': 0.2148, 'beta': 0.2474, 'gamma': 0.2955},
    'Participant 2': {'theta': 0.2531, 'alpha': 0.2289, 'beta': 0.2419, 'gamma': 0.2761},
    'Participant 3': {'theta': 0.2445, 'alpha': 0.2264, 'beta': 0.2478, 'gamma': 0.2814},
    'Participant 4': {'theta': 0.2830, 'alpha': 0.2240, 'beta': 0.2490, 'gamma': 0.2441},
    'Participant 5': {'theta': 0.2605, 'alpha': 0.2294, 'beta': 0.2376, 'gamma': 0.2725},
    'Participant 6': {'theta': 0.2273, 'alpha': 0.2436, 'beta': 0.2504, 'gamma': 0.2787},
    'Participant 7': {'theta': 0.2625, 'alpha': 0.2172, 'beta': 0.2360, 'gamma': 0.2843},
    'Participant 8': {'theta': 0.2411, 'alpha': 0.2565, 'beta': 0.2463, 'gamma': 0.2560}
}

# Last session band powers
last_session = {
    'Participant 1': {'theta': 0.2483, 'alpha': 0.1955, 'beta': 0.2477, 'gamma': 0.3085},
    'Participant 2': {'theta': 0.2333, 'alpha': 0.2548, 'beta': 0.2406, 'gamma': 0.2713},
    'Participant 3': {'theta': 0.2872, 'alpha': 0.2563, 'beta': 0.2000, 'gamma': 0.2565},
    'Participant 4': {'theta': 0.2376, 'alpha': 0.2023, 'beta': 0.2616, 'gamma': 0.2986},
    'Participant 5': {'theta': 0.2329, 'alpha': 0.2546, 'beta': 0.2300, 'gamma': 0.2825},
    'Participant 6': {'theta': 0.2732, 'alpha': 0.2501, 'beta': 0.2353, 'gamma': 0.2414},
    'Participant 7': {'theta': 0.2560, 'alpha': 0.2343, 'beta': 0.2322, 'gamma': 0.2775},
    'Participant 8': {'theta': 0.2373, 'alpha': 0.2425, 'beta': 0.2486, 'gamma': 0.2716}
}

# Calculate the differences
differences = {participant: {band: last_session[participant][band] - first_session[participant][band] for band in first_session[participant]} for participant in first_session}

# Convert to DataFrame for easy manipulation
df_diff = pd.DataFrame(differences).T
print(df_diff)
# Out:
#                 theta   alpha    beta   gamma
# Participant 1  0.0061 -0.0193  0.0003  0.0130
# Participant 2 -0.0198  0.0259 -0.0013 -0.0048
# Participant 3  0.0427  0.0299 -0.0478 -0.0249
# Participant 4 -0.0454 -0.0217  0.0126  0.0545
# Participant 5 -0.0276  0.0252 -0.0076  0.0100
# Participant 6  0.0459  0.0065 -0.0151 -0.0373
# Participant 7 -0.0065  0.0171 -0.0038 -0.0068
# Participant 8 -0.0038 -0.0140  0.0023  0.0156

# %%
# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

df_diff.plot(kind='bar', ax=ax)
ax.set_title('Change in Normalized Band Powers After Intervention')
ax.set_xlabel('Participants')
ax.set_ylabel('Change in Band Power')
plt.xticks(rotation=45)
plt.legend(title='Frequency Band')
plt.tight_layout()
plt.show()

# %%
from scipy.stats import ttest_rel

# Extracting first and last session data
first_df = pd.DataFrame(first_session).T
last_df = pd.DataFrame(last_session).T

# Paired t-tests
for band in first_df.columns:
    t_stat, p_value = ttest_rel(first_df[band], last_df[band])
    print(f'{band.capitalize()} Band: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}')
# Out:
# Theta Band: t-statistic = 0.0924, p-value = 0.9290
# Alpha Band: t-statistic = -0.8118, p-value = 0.4436
# Beta Band: t-statistic = 1.1794, p-value = 0.2768
# Gamma Band: t-statistic = -0.2431, p-value = 0.8149

# %%
import numpy as np

# First session normalized band powers
first_session = [
    {'theta': 0.2422, 'alpha': 0.2148, 'beta': 0.2474, 'gamma': 0.2955},
    {'theta': 0.2531, 'alpha': 0.2289, 'beta': 0.2419, 'gamma': 0.2761},
    {'theta': 0.2445, 'alpha': 0.2264, 'beta': 0.2478, 'gamma': 0.2814},
    {'theta': 0.2830, 'alpha': 0.2240, 'beta': 0.2490, 'gamma': 0.2441},
    {'theta': 0.2605, 'alpha': 0.2294, 'beta': 0.2376, 'gamma': 0.2725},
    {'theta': 0.2273, 'alpha': 0.2436, 'beta': 0.2504, 'gamma': 0.2787},
    {'theta': 0.2625, 'alpha': 0.2172, 'beta': 0.2360, 'gamma': 0.2843},
    {'theta': 0.2411, 'alpha': 0.2565, 'beta': 0.2463, 'gamma': 0.2560}
]

# Last session normalized band powers
last_session = [
    {'theta': 0.2483, 'alpha': 0.1955, 'beta': 0.2477, 'gamma': 0.3085},
    {'theta': 0.2333, 'alpha': 0.2548, 'beta': 0.2406, 'gamma': 0.2713},
    {'theta': 0.2872, 'alpha': 0.2563, 'beta': 0.2000, 'gamma': 0.2565},
    {'theta': 0.2376, 'alpha': 0.2023, 'beta': 0.2616, 'gamma': 0.2986},
    {'theta': 0.2329, 'alpha': 0.2546, 'beta': 0.2300, 'gamma': 0.2825},
    {'theta': 0.2732, 'alpha': 0.2501, 'beta': 0.2353, 'gamma': 0.2414},
    {'theta': 0.2560, 'alpha': 0.2343, 'beta': 0.2322, 'gamma': 0.2775},
    {'theta': 0.2373, 'alpha': 0.2425, 'beta': 0.2486, 'gamma': 0.2716}
]

# Calculate differences
differences = {band: [] for band in first_session[0]}
for band in differences:
    differences[band] = [last_session[i][band] - first_session[i][band] for i in range(len(first_session))]

# Calculate mean difference and standard deviation of differences
mean_differences = {band: np.mean(differences[band]) for band in differences}
std_differences = {band: np.std(differences[band], ddof=1) for band in differences}

# Calculate Cohen's d
cohen_d = {band: mean_differences[band] / std_differences[band] for band in differences}
cohen_d
# Out:
# {'theta': -0.03267119093149766,
#  'alpha': 0.2870168248011651,
#  'beta': -0.41698254297078086,
#  'gamma': 0.08593685636311052}

# %%
import numpy as np

# Data
sig_theta = [0.2309, 0.2236, 0.2486, 0.1217, 0.2491, 0.2485, 0.3056, 0.2464]
scg_theta = [0.2329, 0.2127, 0.2557, 0.2564, 0.2449, 0.2228, 0.2919, 0.2102]

# Calculate means
mean_sig = np.mean(sig_theta)
mean_scg = np.mean(scg_theta)

# Calculate standard deviations
std_sig = np.std(sig_theta, ddof=1)
std_scg = np.std(scg_theta, ddof=1)

# Calculate pooled standard deviation
n_sig = len(sig_theta)
n_scg = len(scg_theta)
pooled_std = np.sqrt(((n_sig - 1) * std_sig**2 + (n_scg - 1) * std_scg**2) / (n_sig + n_scg - 2))

# Calculate Cohen's d
cohens_d = (mean_sig - mean_scg) / pooled_std
cohens_d
# Out:
# -0.16076128715123258

# %%
import numpy as np

# Data for band powers
sig_band_powers = {
    'theta': [0.2309, 0.2236, 0.2486, 0.1217, 0.2491, 0.2485, 0.3056, 0.2464],
    'alpha': [0.2329, 0.2456, 0.1959, 0.0989, 0.2455, 0.2143, 0.2597, 0.2160],
    'beta': [0.2667, 0.2561, 0.2505, 0.1495, 0.2512, 0.2627, 0.2170, 0.2572],
    'gamma': [0.2695, 0.2747, 0.3051, 0.6298, 0.2542, 0.2746, 0.2178, 0.2804]
}

scg_band_powers = {
    'theta': [0.2329, 0.2127, 0.2557, 0.2564, 0.2449, 0.2228, 0.2919, 0.2102],
    'alpha': [0.2225, 0.2175, 0.2460, 0.2258, 0.2416, 0.2306, 0.2767, 0.2159],
    'beta': [0.2609, 0.2750, 0.2432, 0.2464, 0.2528, 0.2633, 0.2202, 0.2244],
    'gamma': [0.2838, 0.2949, 0.2551, 0.2714, 0.2607, 0.2834, 0.2112, 0.3495]
}

# Function to calculate Cohen's d for each band
def cohen_d(sig_data, scg_data):
    mean_sig = np.mean(sig_data)
    mean_scg = np.mean(scg_data)
    std_sig = np.std(sig_data, ddof=1)
    std_scg = np.std(scg_data, ddof=1)
    pooled_std = np.sqrt(((len(sig_data) - 1) * std_sig**2 + (len(scg_data) - 1) * std_scg**2) / (len(sig_data) + len(scg_data) - 2))
    d = (mean_sig - mean_scg) / pooled_std
    return d

# Calculate Cohen's d for each band
effect_sizes = {band: cohen_d(sig_band_powers[band], scg_band_powers[band]) for band in sig_band_powers}
effect_sizes
# Out:
# {'theta': -0.16076128715123258,
#  'alpha': -0.5435395270629654,
#  'beta': -0.3061290273715358,
#  'gamma': 0.3846792085786562}
